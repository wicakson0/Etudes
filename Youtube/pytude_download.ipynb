# %% [markdown]
# # Youtube Downloader with pytube

# %%
from pytube import YouTube

# %%
yt = YouTube("http://www.youtube.com/watch?v=uU5vVT_Cp7c")

# %%
yt.streams.filter(progressive=True)
# Out:
# ---------------------------------------------------------------------------
# RegexMatchError                           Traceback (most recent call last)
# File e:\Programs\miniforge3\envs\GENERAL_SHENANIGANS\Lib\site-packages\pytube\__main__.py:181, in YouTube.fmt_streams(self)
#     180 try:
# --> 181     extract.apply_signature(stream_manifest, self.vid_info, self.js)
#     182 except exceptions.ExtractError:
#     183     # To force an update to the js file, we clear the cache and retry
#
# File e:\Programs\miniforge3\envs\GENERAL_SHENANIGANS\Lib\site-packages\pytube\extract.py:409, in apply_signature(stream_manifest, vid_info, js)
#     401 """Apply the decrypted signature to the stream manifest.
#     402
#     403 :param dict stream_manifest:
#    (...)
#     407
#     408 """
# --> 409 cipher = Cipher(js=js)
#     411 for i, stream in enumerate(stream_manifest):
#
# ...
